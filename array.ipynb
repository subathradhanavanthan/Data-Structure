# %%
arr=[10,20,30,40,50]
for element in arr:
    print(element)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
arr=[10,20,40,50]
arr.insert(2,30)
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr=[10,20,30,40,50]
arr.remove(30)
print(arr)
# Out:
# [10, 20, 40, 50]
